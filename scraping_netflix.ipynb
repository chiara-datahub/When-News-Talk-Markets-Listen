# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from datetime import timedelta

# %%
API_TOKEN = "token"

URL = (
    "https://api.apify.com/v2/acts/"
    "kaitoeasyapi~twitter-x-data-tweet-scraper-pay-per-result-cheapest/"
    "run-sync-get-dataset-items"
    f"?token={API_TOKEN}"
)

# %%
start_date = pd.to_datetime("2022-04-19")
end_date   = pd.to_datetime("2022-05-03")

dates = pd.date_range(start=start_date, end=end_date, freq="D")

# %%
payloads_netflix = []

for d in dates:
    since = d.strftime("%Y-%m-%d_00:00:00_UTC")
    until = (d + timedelta(days=1)).strftime("%Y-%m-%d_00:00:00_UTC")

    payload = {
        "twitterContent": "Netflix streaming market",
        "since": since,
        "until": until,
        "lang": "en",
        "queryType": "Top",
        "maxItems": 100
    }

    payloads_netflix.append(payload)

# %%
import requests
import time

# %%
all_tweets = []

for payload in payloads_netflix:
    print("Scarico:", payload["since"], "→", payload["until"])

    response = requests.post(URL, json=payload)
    tweets = response.json()

    if isinstance(tweets, list) and len(tweets) > 0:
        all_tweets.extend(tweets)

    time.sleep(2)
# Out:
# Scarico: 2022-04-19_00:00:00_UTC → 2022-04-20_00:00:00_UTC
# Scarico: 2022-04-20_00:00:00_UTC → 2022-04-21_00:00:00_UTC
# Scarico: 2022-04-21_00:00:00_UTC → 2022-04-22_00:00:00_UTC
# Scarico: 2022-04-22_00:00:00_UTC → 2022-04-23_00:00:00_UTC
# Scarico: 2022-04-23_00:00:00_UTC → 2022-04-24_00:00:00_UTC
# Scarico: 2022-04-24_00:00:00_UTC → 2022-04-25_00:00:00_UTC
# Scarico: 2022-04-25_00:00:00_UTC → 2022-04-26_00:00:00_UTC
# Scarico: 2022-04-26_00:00:00_UTC → 2022-04-27_00:00:00_UTC
# Scarico: 2022-04-27_00:00:00_UTC → 2022-04-28_00:00:00_UTC
# Scarico: 2022-04-28_00:00:00_UTC → 2022-04-29_00:00:00_UTC
# Scarico: 2022-04-29_00:00:00_UTC → 2022-04-30_00:00:00_UTC
# Scarico: 2022-04-30_00:00:00_UTC → 2022-05-01_00:00:00_UTC
# Scarico: 2022-05-01_00:00:00_UTC → 2022-05-02_00:00:00_UTC
# Scarico: 2022-05-02_00:00:00_UTC → 2022-05-03_00:00:00_UTC
# Scarico: 2022-05-03_00:00:00_UTC → 2022-05-04_00:00:00_UTC

# %%
tweets_df = pd.DataFrame(all_tweets)

# %%
print(tweets_df.shape)
tweets_df.head()
# Out:
# (1040, 31)
#     type                   id  \
# 0  tweet  1516532661803573258
# 1  tweet  1516544297147179009
# 2  tweet  1516511437354455041
# 3  tweet  1516553092837396490
# 4  tweet  1516511634298228738
#
#                                                  url  \
# 0  https://x.com/live2beingu/status/1516532661803...
# 1  https://x.com/goto_finance/status/151654429714...
# 2  https://x.com/screentime/status/15165114373544...
# 3     https://x.com/verge/status/1516553092837396490
# 4    https://x.com/pkafka/status/1516511634298228738
#
#                                           twitterUrl  \
# 0  https://twitter.com/live2beingu/status/1516532...
# 1  https://twitter.com/goto_finance/status/151654...
# 2  https://twitter.com/screentime/status/15165114...
# 3  https://twitter.com/verge/status/1516553092837...
# 4  https://twitter.com/pkafka/status/151651163429...
#
#                                                 text source  retweetCount  \
# 0  #netflix 👀👀👀 this stock needs more than a pray...                   28
# 1  ◆初の会員減\nさきほどのNETFLIX決算。3月の有料会員数は2.21億人で、昨年末比で微...                  382
# 2  Netflix lost 200K subscribers in Q1 and expect...                 3436
# 3  Netflix CEO now says he’s open to a cheaper, a...                  103
# 4  Netflix had to spend a full page of its invest...                   60
#
#    replyCount  likeCount  quoteCount  ...  \
# 0          11        156           2  ...
# 1           6       2201          62  ...
# 2        1436      37573        7594  ...
# 3          87        842         169  ...
# 4           8        188          16  ...
#
#                                     extendedEntities  card place  \
# 0  {'media': [{'display_url': 'pic.x.com/P61nIAUg...  None    {}
# 1  {'media': [{'display_url': 'pic.x.com/3SQZrQBp...  None    {}
# 2  {'media': [{'display_url': 'pic.x.com/R6Km2JKx...  None    {}
# 3  {'media': [{'display_url': 'pic.x.com/WDNcESQd...  None    {}
# 4  {'media': [{'display_url': 'pic.x.com/o5F8AiYD...  None    {}
#
#                                             entities  reply_to_user_results  \
# 0  {'hashtags': [{'indices': [0, 8], 'text': 'net...                   None
# 1  {'hashtags': [], 'media': [{'display_url': 'pi...                   None
# 2  {'hashtags': [], 'media': [{'display_url': 'pi...                   None
# 3  {'hashtags': [], 'media': [{'display_url': 'pi...                   None
# 4  {'hashtags': [], 'media': [{'display_url': 'pi...                   None
#
#   quoted_tweet_results quoted_tweet retweeted_tweet isConversationControlled  \
# 0                 None         None            None                    False
# 1                 None         None            None                    False
# 2                 None         None            None                    False
# 3                 None         None            None                    False
# 4                 None         None            None                    False
#
#    isQuote
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#
# [5 rows x 31 columns]

# %%
tweets_df.loc[0, "url"]
# Out:
# 'https://x.com/live2beingu/status/1516532661803573258'

# %%
cols_to_keep = [
    "id",
    "text",
    "twitterUrl",
    "createdAt",
    "lang",
    "retweetCount",
    "replyCount",
    "likeCount",
    "quoteCount",
    "isReply",
    "isQuote"
]

tweets_clean = tweets_df[cols_to_keep]

# %%
import pandas as pd

tweets_clean["createdAt"] = pd.to_datetime(
    tweets_clean["createdAt"], errors="coerce"
)

tweets_clean["date"] = tweets_clean["createdAt"].dt.date
# Out:
# /tmp/ipython-input-2432581884.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   tweets_clean["createdAt"] = pd.to_datetime(
# /tmp/ipython-input-2432581884.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets_clean["createdAt"] = pd.to_datetime(
# /tmp/ipython-input-2432581884.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets_clean["date"] = tweets_clean["createdAt"].dt.date

# %%
tweets_clean = tweets_clean.drop_duplicates(subset="id")
tweets_clean.reset_index(drop=True, inplace=True)

# %%
tweets_clean.head()
# Out:
#                     id                                               text  \
# 0  1516532661803573258  #netflix 👀👀👀 this stock needs more than a pray...
# 1  1516544297147179009  ◆初の会員減\nさきほどのNETFLIX決算。3月の有料会員数は2.21億人で、昨年末比で微...
# 2  1516511437354455041  Netflix lost 200K subscribers in Q1 and expect...
# 3  1516553092837396490  Netflix CEO now says he’s open to a cheaper, a...
# 4  1516511634298228738  Netflix had to spend a full page of its invest...
#
#                                           twitterUrl  \
# 0  https://twitter.com/live2beingu/status/1516532...
# 1  https://twitter.com/goto_finance/status/151654...
# 2  https://twitter.com/screentime/status/15165114...
# 3  https://twitter.com/verge/status/1516553092837...
# 4  https://twitter.com/pkafka/status/151651163429...
#
#                   createdAt lang  retweetCount  replyCount  likeCount  \
# 0 2022-04-19 21:42:17+00:00   en            28          11        156
# 1 2022-04-19 22:28:31+00:00   ja           382           6       2201
# 2 2022-04-19 20:17:56+00:00   en          3436        1436      37573
# 3 2022-04-19 23:03:28+00:00   en           103          87        842
# 4 2022-04-19 20:18:43+00:00   en            60           8        188
#
#    quoteCount  isReply isQuote        date
# 0           2    False     NaN  2022-04-19
# 1          62    False     NaN  2022-04-19
# 2        7594    False     NaN  2022-04-19
# 3         169    False     NaN  2022-04-19
# 4          16    False     NaN  2022-04-19

# %%
len(tweets_clean)
# Out:
# 974

# %%
cols_to_drop = [col for col in ['isQuote', 'lang', 'createdAt'] if col in tweets_clean.columns]
tweets_clean = tweets_clean.drop(columns=cols_to_drop)

# %%
tweets_clean = tweets_clean[tweets_clean['text'].str.match(r'^[\x00-\x7F]+$', na=False)]

# %%
len(tweets_clean)
# Out:
# 419

# %%
# Percorso di salvataggio del CSV
output_path = "/content/drive/Shareddrives/information project/ANALISI X (Twitter)/Fase 2 - Scraping twitter/tweets_netflix.csv"

# Salvataggio del DataFrame in CSV senza includere l'indice
tweets_clean.to_csv(output_path, index=False)

# Messaggio di conferma
print("✅ CSV salvato correttamente in:")
print(output_path)
# Out:
# ✅ CSV salvato correttamente in:
# /content/drive/Shareddrives/information project/ANALISI X (Twitter)/Fase 2 - Scraping twitter/tweets_netflix.csv
